# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos_mat'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos_por'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos_geo'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos_ing'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos_his'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos_fis'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos_qui'])

# %%
# 1) Seu código aqui
df_mat['quant_questoes_mat'] = 24
df_mat['percentual_mat'] = df_mat['Qt_acertos_mat'] / df_mat['quant_questoes_mat']

df_por['quant_questoes_por'] = 18
df_por['percentual_por'] = df_por['Qt_acertos_por'] / df_por['quant_questoes_por']

df_geo['quant_questoes_geo'] = 8
df_geo['percentual_geo'] = df_geo['Qt_acertos_geo'] / df_geo['quant_questoes_geo']

df_ing['quant_questoes_ing'] = 8
df_ing['percentual_ing'] = df_ing['Qt_acertos_ing'] / df_ing['quant_questoes_ing']

df_his['quant_questoes_his'] = 8
df_his['percentual_his'] = df_his['Qt_acertos_his'] / df_his['quant_questoes_his']

df_fis['quant_questoes_fis'] = 12
df_fis['percentual_fis'] = df_fis['Qt_acertos_fis'] / df_fis['quant_questoes_fis']

df_qui['quant_questoes_qui'] = 12
df_qui['percentual_qui'] = df_qui['Qt_acertos_qui'] / df_qui['quant_questoes_qui']

df = pd.concat([df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui], axis=1)
df.index += 1
df
# Out:
#      Qt_acertos_mat  quant_questoes_mat  percentual_mat  Qt_acertos_por  \
# 1                 6                  24        0.250000               7
# 2                19                  24        0.791667              10
# 3                14                  24        0.583333              16
# 4                10                  24        0.416667               7
# 5                 7                  24        0.291667               2
# ..              ...                 ...             ...             ...
# 96                6                  24        0.250000               4
# 97                8                  24        0.333333               1
# 98               23                  24        0.958333               5
# 99                0                  24        0.000000              10
# 100              11                  24        0.458333              15
#
#      quant_questoes_por  percentual_por  Qt_acertos_geo  quant_questoes_geo  \
# ...

# %%
# 2) Seu código aqui
df['qtd_acertos_total'] = df[['Qt_acertos_mat', 'Qt_acertos_por', 'Qt_acertos_geo', 'Qt_acertos_ing', 'Qt_acertos_his', 'Qt_acertos_fis', 'Qt_acertos_qui']].sum(axis=1)
df['qtd_acertos_total'].to_frame()
# Out:
#      qtd_acertos_total
# 1                   35
# 2                   48
# 3                   50
# 4                   32
# 5                   30
# ..                 ...
# 96                  34
# 97                  27
# 98                  40
# 99                  40
# 100                 42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
df['qtd_questoes_total'] = df[['quant_questoes_mat', 'quant_questoes_por', 'quant_questoes_geo', 'quant_questoes_ing', 'quant_questoes_his', 'quant_questoes_fis', 'quant_questoes_qui']].sum(axis=1)
df['percentual_geral'] = df['qtd_acertos_total'] / df['qtd_questoes_total']
df
# Out:
#      Qt_acertos_mat  quant_questoes_mat  percentual_mat  Qt_acertos_por  \
# 1                 6                  24        0.250000               7
# 2                19                  24        0.791667              10
# 3                14                  24        0.583333              16
# 4                10                  24        0.416667               7
# 5                 7                  24        0.291667               2
# ..              ...                 ...             ...             ...
# 96                6                  24        0.250000               4
# 97                8                  24        0.333333               1
# 98               23                  24        0.958333               5
# 99                0                  24        0.000000              10
# 100              11                  24        0.458333              15
#
#      quant_questoes_por  percentual_por  Qt_acertos_geo  quant_questoes_geo  \
# ...

# %%
# 4) Seu código aqui
segunda_fase = df[df['qtd_acertos_total'] > 45]

print (f'{segunda_fase.shape[0]} alunos tiraram uma nota maior que 45')
# Out:
# 31 alunos tiraram uma nota maior que 45

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
desqualificados = df[(df['Qt_acertos_mat'] == 0) | 
                     (df['Qt_acertos_fis'] == 0) | 
                     (df['Qt_acertos_qui'] == 0)]

desqualificados[['Qt_acertos_mat', 'Qt_acertos_fis', 'Qt_acertos_qui']]
# Out:
#     Qt_acertos_mat  Qt_acertos_fis  Qt_acertos_qui
# 4               10               0               8
# 7                6               0               4
# 11              10               7               0
# 13              20               0               3
# 15               7               4               0
# 21              23               2               0
# 26               0               4               8
# 27              11               0               0
# 28              21               3               0
# 34              14               6               0
# 36              11               0              11
# 50               8               0               8
# 57               7               0               8
# 66               1               0               6
# 67               5               0              10
# 73              11               0               9
# 74               1               0              11
# ...

# %%
print(f'{desqualificados.shape[0]} alunos foram desqualificados.')
# Out:
# 23 alunos foram desqualificados.

# %%
media_desqualificados_his = round(desqualificados['Qt_acertos_his'].mean(), 2)
media_desqualificados_geo = round(desqualificados['Qt_acertos_geo'].mean(), 2)

print('Média dos alunos desqualificados em história: {}.'.format(media_desqualificados_his))
print('Média dos alunos desqualificados em geografia: {}.'.format(media_desqualificados_geo))
# Out:
# Média dos alunos desqualificados em história: 3.43.
# Média dos alunos desqualificados em geografia: 3.22.

# %%
segunda_fase_desqualificados = pd.merge(left=segunda_fase, right=desqualificados, how='inner')
segunda_fase_desqualificados
# Out:
#    Qt_acertos_mat  quant_questoes_mat  percentual_mat  Qt_acertos_por  \
# 0              23                  24        0.958333              11
# 1              21                  24        0.875000              13
# 2              11                  24        0.458333              14
# 3              11                  24        0.458333              16
# 4              23                  24        0.958333              11
#
#    quant_questoes_por  percentual_por  Qt_acertos_geo  quant_questoes_geo  \
# 0                  18        0.611111               6                   8
# 1                  18        0.722222               1                   8
# 2                  18        0.777778               6                   8
# 3                  18        0.888889               3                   8
# 4                  18        0.611111               7                   8
#
#    percentual_geo  Qt_acertos_ing  ...  percentual_his  Qt_acertos_fis  \
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'registros de vacinacao covid ACRE.csv'
df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')
df.head(5)
# Out:
#                                  document_id  \
# 0  b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1  a1acc0b6-1cf6-4c4b-adcb-06b473a0faaf-i0b0
# 2  af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3  4879308e-5050-46bb-b8e2-11fa5646a05c-i0b0
# 4  000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936...              69
# 1  f4e17a9e5354cb45e223d85eda02fb2f76048c801675f5...              81
# 2  6734b26bccf826130ebffa66575977bbe71477b12bcf42...              69
# 3  84a341fd350c1ba7117fccbb4d2df417bc0fac0fffac37...              51
# 4  c59571e19f368d4b0cf08cd3bcabb32e5cd8baad5340f6...              65
#
#   paciente_datanascimento paciente_enumsexobiologico  paciente_racacor_codigo  \
# 0              1951-12-28                          F                        3
# 1              1939-11-22                          M                        3
# ...

# %%
# 1) Sua solução aqui
print('Vacinas registradas nessa base são de:')
print(df.shape[0])
# Out:
# Vacinas registradas nessa base são de:
# 169071

# %%
# 2)
print('Pacientes vacinados são de:')
print(df['paciente_id'].nunique())
# Out:
# Pacientes vacinados são de:
# 120517

# %%
# 3)
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df_pacientes_primeira_dose = df[df['vacina_descricao_dose'] == primeira_dose]
numero_pacientes_primeira_dose = df_pacientes_primeira_dose['paciente_id'].nunique()

print('Quantidade de pacientes que tomaram a 1° dose:')
print(numero_pacientes_primeira_dose)
# Out:
# Quantidade de pacientes que tomaram a 1° dose:
# 119713

# %%
# 3) solução alternativa

# %%
# 4)
pacientes_menores_idade = df[df['paciente_idade'] < 18]
pacientes_menores_idade['paciente_id'].nunique()
# Out:
# 47

# %%
# 5)
df['estabelecimento_razaosocial'].nunique()
# Out:
# 42

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
df_menor_idade = df[df['paciente_idade'] < 18].copy()
df_menor_idade.head(5)
# Out:
#                                      document_id  \
# 1567   fdca313f-b348-422d-94d4-f2c66a87868c-i0b0
# 6250   b7431955-1faa-4c1e-9246-7c1e7b8bb3cb-i0b0
# 9569   fdb8d3b6-14d9-4bcc-9cfe-acd46b4a317a-i0b0
# 11338  647e2301-3ba4-463a-8d1e-2b6f38a4d99e-i0b0
# 15144  7f469e03-bece-49d0-bebc-33ad98e27f54-i0b0
#
#                                              paciente_id  paciente_idade  \
# 1567   f5e6b8c44f7c4d13a87c582def5e8d460435b02f26af8c...              17
# 6250   e1a45c07e3c393d5f0eccf4204a7ceab338f4f06696ecb...              16
# 9569   7cf3b238383a70eeb26841c01817737c9706d5b231e8c2...              17
# 11338  53eb7fed5faa26ad17ce21ee378f28e25399ab7e90bc05...              17
# 15144  dbaa6420d8a815158387668d0a59a19cf2bb63958e35d1...              16
#
#       paciente_datanascimento paciente_enumsexobiologico  \
# 1567               2003-07-18                          F
# 6250               2004-05-18                          M
# ...

# %%
# 2)
df_menor_idade.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_datanascimento', 'paciente_enumsexobiologico',
#        'paciente_racacor_codigo', 'paciente_racacor_valor',
#        'paciente_endereco_coibgemunicipio', 'paciente_endereco_copais',
#        'paciente_endereco_nmmunicipio', 'paciente_endereco_nmpais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumnacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaosocial', 'estalecimento_nofantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoatendimento_codigo',
#        'vacina_grupoatendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataaplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
# ...

# %%
# 3)
df_menor_idade['vacina_categoria_nome'].value_counts()
# Out:
# vacina_categoria_nome
# Povos Indígenas                     33
# Trabalhadores de Saúde               9
# Povos e Comunidades Tradicionais     9
# Comorbidades                         2
# Faixa Etária                         1
# Name: count, dtype: int64

# %%
# 4)
lista_variaveis = ['estabelecimento_valor',
       'estabelecimento_razaosocial', 'estalecimento_nofantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']
df_menor_lista = df_menor_idade.loc[:,lista_variaveis]
df_menor_lista.head(5)
# Out:
#        estabelecimento_valor  \
# 1567                 2001314
# 6250                 6917291
# 9569                 6159087
# 11338                2000040
# 15144                7625855
#
#                              estabelecimento_razaosocial  \
# 1567              PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 6250                  PREFEITURA MUNICIPAL DE RIO BRANCO
# 9569             PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 11338                      PREFEITURA MUNICIPAL DE FEIJO
# 15144  DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
#
#                                 estalecimento_nofantasia  \
# 1567                             ESF JOAO ALVES DA SILVA
# 6250   DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 9569    SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL
# 11338                  CENTRO DE SAUDE DIAMANTINO MACEDO
# 15144                  POLO BASE DE MARECHAL THAUMATURGO
#
#        estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# ...

# %%
# 5)
df_menor_lista = df_menor_lista.drop_duplicates()
df_menor_lista.head(5)
# Out:
#        estabelecimento_valor  \
# 1567                 2001314
# 6250                 6917291
# 9569                 6159087
# 11338                2000040
# 15144                7625855
#
#                              estabelecimento_razaosocial  \
# 1567              PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 6250                  PREFEITURA MUNICIPAL DE RIO BRANCO
# 9569             PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 11338                      PREFEITURA MUNICIPAL DE FEIJO
# 15144  DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
#
#                                 estalecimento_nofantasia  \
# 1567                             ESF JOAO ALVES DA SILVA
# 6250   DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 9569    SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL
# 11338                  CENTRO DE SAUDE DIAMANTINO MACEDO
# 15144                  POLO BASE DE MARECHAL THAUMATURGO
#
#        estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# ...

# %%
lista_estabelecimentos_df_menores_18 = df_menor_idade['estabelecimento_razaosocial'].drop_duplicates()
lista_estabelecimentos_df_menores_18.reset_index(drop=True, inplace=True)
lista_estabelecimentos_df_menores_18.index += 1
lista_estabelecimentos_df_menores_18.to_frame()
# Out:
#                           estabelecimento_razaosocial
# 1              PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 2                  PREFEITURA MUNICIPAL DE RIO BRANCO
# 3             PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 4                       PREFEITURA MUNICIPAL DE FEIJO
# 5   DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 6                PREFEITURA MUNICIPAL DE PORTO WALTER
# 7                PREFEITURA MUNICIPAL DE ASSIS BRASIL
# 8                    PREFEITURA MUNICIPAL DE TARAUACA
# 9   DISTRITO SANITARIO ESPECIAL DE SAUDE INDIGENA ...
# 10    DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA
# 11              SECRETARIA DE ESTADO DE SAUDE DO ACRE
# 12                                MINISTERIO DA SAUDE
# 13                 PREFEITURA MUNICIPAL DE PORTO ACRE
# 14                     PREFEITURA MUNICIPAL DE JORDAO
